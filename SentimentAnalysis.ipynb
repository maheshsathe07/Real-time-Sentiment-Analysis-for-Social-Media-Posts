# %%
# Import necessary libraries
import nltk
import random
from nltk.corpus import twitter_samples
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Download NLTK resources
nltk.download('twitter_samples')
nltk.download('stopwords')
nltk.download
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# <bound method Downloader.download of <nltk.downloader.Downloader object at 0x7a330d14d5d0>>

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
tweets = positive_tweets + negative_tweets

# %%
labels = [1] * len(positive_tweets) + [0] * len(negative_tweets)

# %%
def preprocess_tweet(tweet):
  lemmatizer = WordNetLemmatizer()
  stop_words = set(stopwords.words('english'))
  # Tokenize
  tokens = word_tokenize(tweet.lower())
  # Remove stopwords and non-alphabetic tokens
  tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha() and token not in stop_words]
  return ' '.join(tokens)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
preprocessed_tweets = [preprocess_tweet(tweet) for tweet in tweets]

# %%
preprocessed_tweets
# Out:
# ['followfriday top engaged member community week',
#  'hey james odd please call contact centre able assist many thanks',
#  'despiteofficial listen last night bleed amazing track scotland',
#  'congrats',
#  'yeaaaah yippppy accnt verified rqst succeed got blue tick mark fb profile day',
#  'bhaktisbanter pallaviruhail one irresistible flipkartfashionfriday http',
#  'like keep lovely customer waiting long hope enjoy happy friday lwwf http',
#  'impatientraider second thought enough time dd new short entering system sheep must buying',
#  'jgh go bayan bye',
#  'act mischievousness calling etl layer warehousing app katamari name implies p',
#  'followfriday top influencers community week',
#  'would love big juicy selfies http http',
#  'follow jnlazts amp http follow u back',
#  'jjulieredburn perfect already know waiting',
#  'great new opportunity junior triathletes aged gatorade series get entry http',
#  'laying greeting card range print today love job',
#  'friend lunch yummmm nostalgia tb ku',
#  'rookiesenpai arcadester id conflict thanks help screenshot working',
#  'hi liv',
#  'hello need know something u fm twitter sure thing dm x http',
#  'followfriday top new follower community week',
#  'rossbreadmore heard four season pretty dope penthouse obvs gobigorgohome fun',
#  'yeah suppose lol chat bit x',
#  'hello get youth job opportunity follow gt gt tolajobjobs',
#  'seen year',
#  'bosslogic amellywood arrowwriters thank',
#  'hope rest night go quickly bed got music fix time dream',
#  'spiritual ritual festival népal beginning left see http',
#  'hey sarah send u email bitsy help asap',
#  'izzkamilhalda lols',
#  'kik kik kikme lgbt tinder nsfw akua cumshot http',
#  'kalinwhite come house',
#  'effective press release distribution result link removed pressrelease newsdistribution',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'everyone watch documentary earthling youtube',
#  'jamiefigsxx follow jnlazts amp http follow u back',
#  'followfriday michelbauza invataonline top support community week',
#  'buuuuuuuut oh well',
#  'leisuremarkltd noshandquaff aktarislam keanebrands heritagesilver looking forward visiting next week letsgetmessy jo',
#  'sehunshinedaily make u feel better never see anyone kpop flesh',
#  'cathstaincliffe good girl best wish',
#  'great enough reason listen one epic soundtrack',
#  'aquadesigngroup thank shout great friday',
#  'added video youtube playlist http im back twitch today going league',
#  'would love see dear jordan waiting firdoz visitjordan dannyprol',
#  'oh okay thanks',
#  'sssniperwolf like fake gameplays haha im kidding im kidding good stuff',
#  'dennislami yeah exactly',
#  'new product line etsy shop check http boxroomcrafts',
#  'peakyourmind hope vacation going great',
#  'groovinshawn rechargeable normally come charger u buy',
#  'followfriday top engaged member community week',
#  'well asleep one talk sooo someone text',
#  'brynybrath smallcappy yes suppose bet blue fit hearing speech today pity',
#  'green garden midnight sun beautiful canal dasvidaniya till next visit',
#  'keithrparsons scouting sg future wlan pro conference asia',
#  'wazimotometal durooooooo spigranty good u better change lollipop',
#  'lt u nez agnezmo http',
#  'littlemix follow please big dream',
#  'elemaaan oley',
#  'cowokaddict mama reason stand stronger',
#  'macatangayapril follow jnlazts amp http follow u back',
#  'boukendreamer oh god misty baby cute',
#  'bhaktisbanter love blue flipkartfashionfriday http',
#  'carcassdrop woohoo ca wait signed yet still thinking mka',
#  'liam access',
#  'syuhxdxtengku welcome',
#  'stats day arrived new follower unfollowers via http',
#  'surprised amazing figure',
#  'followfriday murtishaw frtechstartups top influencers community week',
#  'happybirthdayemilybett emilybett wishing best beautiful sweet talented http',
#  'plan day drain great',
#  'got ta love timezones p',
#  'parent proud lol least maybe sometimes get happy grade al http',
#  'grande http',
#  'chosen follow twitter http thanks follow',
#  'syazwanzainal sure let know around side world eh u take care',
#  'followfriday superninjaalan top new follower community week',
#  'finally fucking weekend',
#  'real',
#  'lolesportspedia thanks',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'yes joined hushedcallwithfraydoe call amp gift lt got ta get hushedapp http',
#  'yaslarry yeahhh',
#  'dm amp make night better',
#  'joined hushedpinwithsammy event might get text sammywilk day luv u hushedapp http',
#  'would really appreciate share video around http',
#  'hello get youth job opportunity follow gt gt tolajobjobs',
#  'tomparker oh wow beautiful tom',
#  'love syreenanne http',
#  'added video youtube playlist http im back twitch today going league',
#  'followfriday americanograin pecomep apaulicand top support community week',
#  'follow jnlazts amp http follow u back',
#  'gym monday ca wait like',
#  'harnilizalouis hey invite join scope influencer http',
#  'friend know',
#  'waiting nude',
#  'jacobwhitesides go sleep u',
#  'stats day arrived new follower unfollowers via http',
#  'birthday week today',
#  'want cool',
#  'axerade haw phela looking like mom obviously looking like',
#  'zaynmalik prince charming stage x http',
#  'really good luck',
#  'stats day arrived new follower unfollowers via http',
#  'followfriday dcarsoncpa top engaged member community week',
#  'twentyonepilots tyler hipster glass',
#  'martyrafenstein hey marty glad see twitter',
#  'ukbusinesslunch hi joining today',
#  'lafitnessukhelp done thanks',
#  'already afternoon let read al kahfi day finish',
#  'ohmyg yaya dub mainedcm im done stalk ig accnt gondooo moo tologooo haha',
#  'rozbabes invite become scope influencer detail http',
#  'followfriday ngourd locita top influencers community week',
#  'kevinthewhippet spanielharry thanks zzz xx',
#  'physiotherapy friday hashtag today custom',
#  'know monica miss yeah sound good',
#  'good morning beautiful take',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'mandascapinello oh yeah definitely going try tonight took advice treviso',
#  'morallosanthony follow jnlazts amp http follow u back',
#  'nikkieriozzi hi would like impastel concert let know city country start working thanks',
#  'fine gorgeous friday friend xo http',
#  'oven roasted garlic olive oil sun dried tomato dried basil century tuna http',
#  'hostmyoffice nigelpwhittaker lemezma right back atchya great day everyone',
#  'flashhayer even follow back',
#  'future almost http',
#  'followfriday michelploria myfrenchcity jasoncreation top new follower community week',
#  'chance',
#  'mrclivec pcdkirkwood emwilliamscccu laurargallagher cheer',
#  'thatguycalledp go po ice cream',
#  'agree',
#  'spazzytsukihara hehehehe thats point p',
#  'kalinwhite next time stay home',
#  'thanks',
#  'followfriday intlboost top support community week',
#  'stayfaboo soon promise',
#  'web whatsapp volta funcionar com iphone jailbroken',
#  'crustyolddeen plan watching later min leia appears hologram w message obi wan sits w luke',
#  'inter ucl arsenal small team right',
#  'passing dewsbury railway station dew nationalrailenq dewsbury west yorkshire http',
#  'clearlyarticle smh',
#  'uptommosass live scotland strange imagine megan xx',
#  'bookmyshow masaantoday masaantoday shweta tripathi masaantoday masaantoday',
#  'wforwoman w kurta mom half number wsalelove',
#  'ah hello back larry transworldbooks http',
#  'anyway friday looking kinda gooood',
#  'follow jnlazts amp http follow u back',
#  'lol well life thank god enn http',
#  'ojbj holmesjsamuel surely could warmup morning coming bath xx',
#  'dum dum andar ram sampath sona mohapatra amp samantha edward mein tulane razi razi wah josh http',
#  'justinbieber always smile',
#  'picture',
#  'arsenalnewsasit thanks time right perfect timing',
#  'followfriday izywaylesexpats inxpresscoazur top engaged member community week',
#  'juleeyaanaa know',
#  'giveitup already given gas subsidy long back initiative proposed feeling delighted done',
#  'dayloladay missed yesterday',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'lmaoo best song ever lt shall little throwback week p',
#  'clazziebritchas go outlying island cheung chau mui wo totally different',
#  'kfckitchentours kitchen clean totally amazed',
#  'cybelxxx follow jnlazts amp http follow u back',
#  'cusp testing water hope rewarding',
#  'followfriday broadcastbeat insunwetrust conseilsmkg top influencers community week',
#  'arummzz let go drive p traveling traveler yogyakarta jeep indonesia http',
#  'anyone wan na skype',
#  'agylyxa may look bit real nice friendly girl',
#  'im like',
#  'watching concert film',
#  'congratulation winner cheesydelights contest please dm u address contact number',
#  'great weekend guy http',
#  'followfriday clararojasg top new follower community week',
#  'puamagasiva cool seeing film today',
#  'check email marketing http wo regret buy',
#  'vineshpomal lol come join u see u around hour u leave without delay',
#  'actually easy like must station guess train take least hour shifting engine etc',
#  'sunburn peeling',
#  'visit blog http thanks',
#  'tikosd hi would like impastel concert let know city country start working thanks',
#  'talk help',
#  'cassthetrainer huge amp warm welcome vodkablond finally complete triangle',
#  'luciennediver live northern ireland sight seen',
#  'follow jnlazts amp http follow u back',
#  'followfriday tivipro compexly top support community week',
#  'stats day arrived new follower unfollowers via http',
#  'imraina feeling smthng smthng fr u lol wan na hug u xoxo love uu jaann take care lt',
#  'thanks mom',
#  'thanks topnewfollowers bestofficpad mrcfluegel jeanmarcpn happy connect',
#  'mooseallain meatbingo wonderful thing made feel fluffy inside great pirouette moose',
#  'kristophcajon trip philly december love come dude',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'question flawed pain negate strength http',
#  'reflectknives went solo move made',
#  'hey fav nirvana song smell like teen spirit rip amy winehouse',
#  'followfriday ccidelyon top engaged member community week',
#  'let go drive p traveling traveler yogyakarta jeep indonesia http',
#  'name couple yet tomhiddleston elizabetholsen yaytheylookgreat',
#  'love goodnight vid going wake love one',
#  'weekend gon na shoot lovely narakubrock lt picture made last time http',
#  'anyway',
#  'itty bitty teenie bikini http http',
#  'joined hushedpinwithsammy event might get text sammywilk day luv u hushedapp http',
#  'always much fun hour get together ending night ice cream xfiles content',
#  'aangelayap easy',
#  'nttownend yes surprised see bit rain today',
#  'reyesfraulein follow jnlazts amp http follow u back',
#  'fatpunkstudio fabulous friday keep fantastic work',
#  'justinbieber please follow please jb follow love always forever belieber love u',
#  'followfriday diplomix top influencers community week',
#  'morning',
#  'franchiseedsuk good hear',
#  'nighty night let bed bug bite',
#  'bonsplansblog beautiful bracelet good idea',
#  'guywilliamsguy waiting foundry',
#  'kalinwhite like game',
#  'suzannepanter kevinbacon katosman ah make sense see pic effing phone last night woot x',
#  'hi derek could try using parkshare gloucestershire http',
#  'aaaahhh man track traffic stress reliever',
#  'followfriday nyibf top new follower community week',
#  'today dear',
#  'jesutomisin hear guy want arbeloa',
#  'shawnmendes turning day omg least year difference',
#  'matteomeacci well say europe rise find hard believe',
#  'wforwoman wsalelove uncountable coz love unlimited',
#  'yes course teampositive http',
#  'yes love aldub',
#  'laurenarren drparkave dheracing rhoachri barbarabathurst willisteam thank rita',
#  'mikerobb hi could please dm u info happy help',
#  'way boy',
#  'graphure hope get lot nice gift',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'followfriday promosalonsinfo top support community week',
#  'true http',
#  'added video youtube playlist http im back twitch today going league',
#  'zarlashtfaisal sethi high',
#  'exe skeem saam',
#  'people make smile lilfrenchmsp http',
#  'coschedule thanks invite',
#  'syedihusain polite izzat wese trust khawateen k sath selfies say mana kar deya',
#  'thank movietubepw friday evening sorted',
#  'smart',
#  'vaalthepal nice hair tbh',
#  'year http',
#  'jacob amp g upgrade',
#  'heydonworks nice tee man',
#  'happy family vacation pic http',
#  'sleep would nice',
#  'reading beautiful like read',
#  'talking one person two conversation',
#  'skype fun',
#  'soggystones online',
#  'friday http',
#  'followfriday ccifccanada adamevnmnt top engaged member community week',
#  'something get friday great start great day mclaren fridayfeeling tgif http',
#  'avinpera follow jnlazts amp http follow u back',
#  'square enix bissmillah ya allah',
#  'sephtonmark training socent startup tobaccodocklon week helpingb love drop youre arnd town',
#  'hgvwolfie basically piss cup test',
#  'ellenrstewart next',
#  'ionswitz notch also twitter terrible complicated discussion',
#  'snapchat lynettelowe snapchat kikmenow snapme hot snapchat amazon kikmeguys http',
#  'looking forward hour shift today',
#  'definately agree growing sport drop email detail see',
#  'last rt',
#  'rakyat keep visiting blog reading writing http',
#  'ever since mentioned fly fishing day getting follows promoted post lol cyber stalked',
#  'gurmeetramrahim ourdaughtersourpride mypapamypride proud papa coach',
#  'imarpita great talking',
#  'never see positive kha u could also mention atleast going',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'omundson mango lassi monty marvellous though suspect meant',
#  'followfriday stayfanchemin aandreup top influencers community week',
#  'haha yes hr time come touch kepler chalna hai',
#  'follow jnlazts amp http follow u back',
#  'allygrrdo thankyou pretty',
#  'pinkpeoniesblog helloprettysa definitely hazel food market brooklyn pta gt gt http',
#  'still awake',
#  'joiredve okayy',
#  'awww thank http',
#  'ha surprise least okay see doc afternoon yorkshire splendid though xx',
#  'jrturnerphoto davidqueenan jameslturnbull spam folder wow huge amount need travel nigeria claim',
#  'perksofnialljh rted good luck',
#  'leg hurt bad',
#  'get mine saturday',
#  'imafaithreyes thaaanks december puhon',
#  'http',
#  'payumoney true change tnc without prior notification could used last night',
#  'http probably find funny',
#  'aliyaskates yoshihikomkm fat co probably ate yuna',
#  'emmajaneparsons curiousmindsnw fun tameside',
#  'hydrcted',
#  'charmingjedward welcome',
#  'account http',
#  'call scouser everything hope zoe well mate',
#  'right literally like maybe u get people actually know studenttrip',
#  'rest well http',
#  'edgarslame happy birthday edgar hope good one keep updating travel log',
#  'hello vikkfollows',
#  'marreyjewana bring abes',
#  'stats day arrived new follower unfollowers via http',
#  'someone talk',
#  'never ever meet',
#  'bbcsport come man',
#  'follow jnlazts amp http follow u back',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'livelykaty sigh dreamily pout bath eye quacketyquack',
#  'happy birthday love',
#  'brianscrooks burwellitltd cheer',
#  'funny happened phil',
#  'wmfiredogs call del amp rodders else',
#  'forkh hi may like play newest gamejam game would happy http',
#  'great irish literature really inaccessible u without irish',
#  'bhaktisbanter pallaviruhail yeah fun flipkartfashionfriday',
#  'nice music check http',
#  'strange kareena fan knowing kareena fan',
#  'hello get youth job opportunity follow gt gt tolajobjobs',
#  'better',
#  'artforcause cool look',
#  'beautiful http',
#  'playing brain dot braindots http http',
#  'screamqueenlr fair enough would rush back either',
#  'brandi fb drop selfie fun http',
#  'kthrnbyln follow jnlazts amp http follow u back',
#  'carnival men put mask mask xavier forneret',
#  'jennifer check site u wan na get free ball pool coin thank',
#  'beautiful edit trish loved',
#  'gratefulness happiness post three thing grateful today comment',
#  'love wakeup beside amp real dirty dirty sex http',
#  'literalwt lmaooo hot like louis hot',
#  'gon na throw idea cause bad inspire think something much better',
#  'ff best twoofs follow wkend allpawone ddwalks pawsforawalk http',
#  'cinnamoniboni wish could maybe one year',
#  'hey guy',
#  'think need go bed kind exhausted good night twitter',
#  'renukavyavahare thank much glad liked',
#  'get better time',
#  'kind word thank much sueryderlch much good cheltenham area',
#  'hi beautiful follow please iggyazalea lanadelrey megannicole madisonellebeer tiffanyalvord',
#  'kale crisp ruin good thing',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'open worldwide',
#  'get fuck outta http',
#  'streetfighter cool guy sfvbeta release work',
#  'crazyleonet woodslenny msportltd fordperformance really look vantastic vbgie fordownersclub autocultureirl',
#  'today finally time work xcylin',
#  'upcireland thank bundle show internet price phone realisticly paying net',
#  'publicprotector true education powerful weapon use change world nelson mandela',
#  'follow jnlazts amp http follow u back',
#  'recent trip j amp k totally loved flow pakistan incredibleindia http',
#  'teenchoice choiceinternationalartist superjunior',
#  'caught first salmon today',
#  'annaelerihart happy friday checking see enjoyed',
#  'mrsmanfydiston thanks following get touch like info project youth',
#  'please go check awesome friend stream http fantastic artist',
#  'alma mater highschooldays clientvisit faith christian school http',
#  'good luck lizaminnelli upcoming uk appearance garyjhorrocks scottgorenstein http',
#  'lol ca believe beautiful girl like single p',
#  'never listening hill every',
#  'dantoml would listen beat went wrong life',
#  'haha great',
#  'getting everything ready natural pefumery workshop neals yard covent garden tomorrow http',
#  'grannaharmony fback indo harmos',
#  'ewoksurewok americano',
#  '',
#  'squadkathniels bernardokath love way lt',
#  'thevaas always remember',
#  'aww thank beautiful pic http',
#  'head',
#  'hi saw u follow thought u might like dark http let u know u think',
#  'smart handshome cute juga http',
#  'laurasummersnow stwevents hurray looking forward meeting',
#  'tomokawaiix follow jnlazts amp http follow u back',
#  'liilss cause hate course lol cant decide want change im going take time save maybe travel',
#  'woollywormhead list still show',
#  'realiseagency',
#  'loretam hi would like impastel concert let know city country start working thanks',
#  'danisnotonfire amazingphil oh awesome thank much',
#  'caityyoungblood perfect',
#  'lcfcset hiya email web exec able help',
#  'enjoy photo mom baby http',
#  'big thx bikechainricci kind support shineukcharity shineballoons good luck',
#  'china actually girl homosexual love either way hyungbot',
#  'cause like lot',
#  'mattghouse give time fam got thing mind',
#  'thanks god friday jgh',
#  'ashtonparsonsuk lypsyluk lovely',
#  'heartsouthwest timetunnel quite sure radio set heart',
#  'jackgilinsky hiii jack ily',
#  'smartcookiesam confarreo played domino pub got quite heated enjoyed though',
#  'hostclubhowell prob',
#  'danvpeterson enjoy sorry hastily typed message',
#  'ff dreamshakes marketsmatter mrsmarketuk cheshireladders streetzine blueappleheroes thank',
#  'say big thank person came idea screenshotting',
#  'ashrafuzma rtaluvedafridi true pakistani p',
#  'mention',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'dreamteam gooo bailey pbbabscbn',
#  'thank',
#  'addictionguy drank',
#  'ernezpjy old pic',
#  'follow jnlazts amp http follow u back',
#  'gotten sleep hour',
#  'welsh wale today yippee http',
#  'done',
#  'fwmkian happy birthday baby miss much love much',
#  'thanks bro x',
#  'thats lord http',
#  'sweet http',
#  'like michael thanks kind word cheer em',
#  'morning really u already fun cause weekend right ure future amazing night',
#  'waiting people call bigot p http',
#  'yezzer usually front back squat',
#  'much fun really enjoyed hope next contest coming soon',
#  'dobar dan brand new heavy http',
#  'chileeers look like great way spend friday afternoon enjoy marathon iflix',
#  'itsalliefx need someone talk always keep head',
#  'officially graduated http',
#  'glad cry http',
#  'thanks',
#  'applewriter yep expert bisexuality good luck',
#  'minal aidzin yo pi',
#  'imlexapadilla follow jnlazts amp http follow u back',
#  'riverford plan read brand new cook book figure make dinner tonight',
#  'snxy lol tough choice tbh really like every song others p',
#  'jessopjill welcome',
#  'chill smu oval basketball player whahahaha soamazing http',
#  'moment decide log onto account year moment saw best thing ever http',
#  'wforwoman girl wardrobe would w wsalelove',
#  'new user',
#  'welcome back teamred',
#  'oh apparently already member lol hopefully able come depends time',
#  'greatly appreciated',
#  'lnnamnd hi made change design hope like http',
#  'makotobio ahhh yes',
#  'cinepambata video festival complete mechanic official entry form may downloaded http sali na',
#  'hello get youth job opportunity follow gt gt tolajobjobs',
#  'woodotamel follow jnlazts amp http follow u back',
#  'ur mom getting u swishers ur copping monday http',
#  'song week ducktails surreal exposure sotw http jingly jangly loveliness',
#  'halesowen blackcountryfair tomorrow follower going come say hello stand high street',
#  'good luck georgeejgibsonn assessment today http',
#  'etherealmind mental strength',
#  'tsmagiccandy looking beautiful amazing body ooze sex appeal xx',
#  'home amassiveoverdoseofships http latest vid way enjoy visit site',
#  'theemblaze cnni isi chan',
#  'sonymax amp c noted pkwalasawaal',
#  'stats day arrived new follower unfollowers via http',
#  'gemmapriceuk thanks follow gemma enjoy new orleans',
#  'potus fever finally caught geskenya obamainkenya magicalkenya greatkenya allgoodthingske',
#  'funny next anime umaru',
#  'sothcott caseybatchelor great singer',
#  'follow jnlazts amp http follow u back',
#  'amiibofiguresuk look like game ship u got order',
#  'take room amp car gone cool http',
#  'going streaming soon',
#  'thanks',
#  'hi would like impastel concert let know city country start working thanks',
#  'hahaha everyone fun story related song got labeled worst batch principal due p',
#  'get stuff like march release one first starting new one',
#  'ff top twoofs wooftastic wkend guy merlynthecollie barksbunnies jesspals mollysniffs wobblycollie http',
#  'descenthypnosis well received necessary http',
#  'ayushmannk long time see p',
#  'regret rn tomorrow morning whatever',
#  'badboybunny clawzskunk hat',
#  'bergsplace runjumpscrap thatchamdad simplybeingmum loopyrach mummyvsdaddy harryshonestmum thank',
#  'never love life success',
#  'abstinence',
#  'wtf never happened moment may may like surprise thrown',
#  'start middle finished http',
#  'im back twitter',
#  'jackjackjohnson ended happy',
#  'marthasydenham alexxdouglas wordpressdotcom lovely stuff need repeated relentlessly approximately next year',
#  'smileformeacc hug many',
#  'runescape oldschoolrs oldschool runescape',
#  'ourseasidebaby mrsrobinsonme thanks shout wonderful weekend',
#  'rest day http',
#  'lovely daaay',
#  'lt lt lt frnds feeling blessed',
#  'sense',
#  'littlemisslilia emintrouble awww pussycat xx',
#  'hope everything going great lol',
#  'pinkpeoniesblog helloprettysa market main launched pretoria',
#  'care care http fahrinahmad tengkuaaronshah eksperimencinta',
#  'tykkäsin http special paysafecard giveaway lue desc',
#  'month waiting finally hoodie eeeep yay sohappyrightnow',
#  'filikirisha mmmmmm c lovely babe',
#  'normabattle thx feedback glad gained value',
#  'good night lovely hope peaceful night rest feel refreshed wake sweet dream',
#  'never get used thank much',
#  'thinkingdifrnt thanks manthan stay tuned u',
#  'blogadda freshness beautiful smile mother amp determination make day maxfreshmove',
#  'playing brain dot braindots http http',
#  'jamesbourne please james think beautiful girl loneliest tattoo changed life http',
#  'hi girl happy magnificent fantastic lorishemek thebikinichef agingbackwards pilatesbodynyc',
#  'southasianartuk keranjeet achieved together thank rashmi time dedication complete inspiration',
#  'ff happyfriday szekifer djchiavistelli weekend nearly',
#  'biblioticaa retweeted',
#  'naturalsystah updated soon sure sign set text alert',
#  'something new http',
#  'dang rad abzugame fanart http',
#  'hardcoregooners tashagunners zannatur nativenoddy cheer tgif',
#  'massive congrats niamh fennell journalism graduate land dream job copying amp pasting tweet http',
#  'elbow meatbingo govindajeggy thank',
#  'stats day arrived new follower unfollowers via http',
#  'yes thank',
#  'ariana grande selena gomez louis tomlinson rita liam payne caradelevingne trade solo dm',
#  'domsequitur tired fine',
#  'ohvdqohcdjroc nope definitely still apply year want iamca',
#  'ashleylynch wetsprocket ah found thanks',
#  'aftie p',
#  'goodmorning',
#  'annemorbs follow jnlazts amp http follow u back',
#  'bjoernknafla exactly look going',
#  'prokabaddi koel mallick yourkoel recites national anthem starsportsindia http',
#  'yournaturalleaders youngnaturalleaders cumbria uk yournaturallead amp flockstars itv http',
#  'goodmorning goodnight sleeptight haveagoodday',
#  'one leg september perhaps bb promote full album september http',
#  'still fully intend write many game design possible attack plan next month gt',
#  'bird come join u little fun teamadmicro http',
#  'thecigirl leroihaptalon stpierjane headwaygsy cheshiregsy fridaydownpour hope clear wkend good one',
#  'time sleep',
#  'three word rohit http',
#  'xxgoodgoddessxx gorgeous queen god',
#  'long wait otwolgrandtrailer',
#  'get inspired sheer fact obama beat innumerable odds become u president ni shauri yako memotohaters',
#  'everyone go drop pwincessly follow stream http',
#  'nanavisitor happy birthday sunday hope great day lot pampering love',
#  'great thank',
#  'going cabincrew interview langkawi august please wish luck airasia tonyfernandes http',
#  'tlntweets nutzaudio interflorauk icelandfoods ilovehq thank',
#  'fulfil fantasy http http',
#  'virtuallykaren cool thanks thinking hope well',
#  'follow jnlazts amp http follow u back',
#  'krissydclayton thank much babe',
#  'side please',
#  'ohsexycyruz thanks bro x',
#  'tomparker great day',
#  'make much sense lol',
#  'bertolaccitweet wait inter',
#  'ff mrshhundal higginsrecruit kioskatthepark great weekend',
#  'uptownjavin chloeeelmoree eymvnique family gt gt friend',
#  'apartment makeover http great idea factory living',
#  'orchardtearoom madsenjewellery thanks amp welcome hope go brilliantly',
#  'emilybett happyyyyyy birthdaaaaayyyy',
#  'come kill',
#  'zaloraid hi im interested internship program sadly cant access career page u help issue',
#  'dischanmedia sad hear thank much overwhelmingly beautiful game thank hard work',
#  'murrayyyyyyyy aha yes looking forward seeing',
#  'happy friday beaut ff sophieintsticks catecawley jasmoonbutterfl http',
#  'halfwaytohemmo love help http',
#  'bionsenbeauty would love win deo faaaaaabulous freebiefriday aluminiumfree stayfresh xx',
#  'mrlythgoe meatbingo yes john',
#  'ithloopwithcoco thanks worry navigate blog check',
#  'thnks progrmr',
#  'bet well wo getting sleep shift quit hard work thank xx',
#  'arabicaah figure',
#  'andreaholzner hardly surprising rose inspire much emotive poetry',
#  'followed',
#  'iflyflat joined virginaustralia frequentflyer program',
#  'always end breaking apologizing fuck nice',
#  'tonywhittaker fabulous well hope great day',
#  'musictubenl hi would like impastel concert let know city country start working thanks',
#  'ignitionphoto welcome',
#  'huncoy visit blog http thanks',
#  'enjoy londondairy icecream share u experience',
#  'follow jnlazts amp http follow u back',
#  'playacreep luv ur',
#  'craftbeercoll past hoodie cover lot sin',
#  'astonmerrygold bet excited xxxxxxx good luck hope get number one',
#  'msljim welcome jim made chuckle train morning happy friday',
#  'kageyashsa shopping bit p',
#  'jadethemong agreed haha p',
#  'bakingbar happy birthday positive full cake',
#  'nobicate doh subscriber needed please let u know reached number',
#  'good thanks hope well xx',
#  'dry hot scorching summer ff infocffm mediationmk exetermediation kentfms essexmediation',
#  'pallavijha maybe younger woman stamen tom gt',
#  'digestdigital thing looking great either expect anything le lol least weekend',
#  'finally get bed good night tweeties',
#  'bangaloretrance thanks guy',
#  'alistairbeech fab thank support',
#  'turnuptexas really dont love much',
#  'ff follow gt loner side please',
#  'riahannenavarro charger',
#  'http',
#  'electricgecko introducing new word altering understanding word x spreading either big problem',
#  'follow jnlazts amp http follow u back',
#  'ff wooftastic twoofs hope supa dupa weekend mypackofwolves skythegsd helvellyn bennyboygr http',
#  'clivewalker near enough dartmoor',
#  'gon na stay gold colour hopefully come soon thank anyway',
#  'follow back',
#  'yay ok',
#  'someday know',
#  'u r dii n cant forget si',
#  'jgh fr smf amp ft girl lt',
#  'maybe get japanese import hello kitty matching stationary',
#  'weekend drawing close plan http',
#  'peterlizmaher hi saw u follow thought u might like dark http let u know u think',
#  'hello twitter account broken',
#  'hi thanks connecting specialise thermal imaging survey need u',
#  'drnomansheikh nice',
#  'please follow back onedirection x',
#  'hi want get connected koreacholics planning come south korea',
#  'aremay oh fact p',
#  'planned nice scamper slept alarm two hour suppose needed sleep ai mad',
#  'alanessyahmad chweina xd jotzh dude go school waste time twitter',
#  'stellaandlouise hiya yep show take place completely cover worth bringing coat beforehand tho foh outside',
#  'nicagaray thanks',
#  'alrightpet enjoy holiday',
#  'seen many since finished jojo',
#  'susansuzt simonbedford ta',
#  'thank always last back track hope fantastic weekend http',
#  'cotterw urihoresh make better though',
#  'stats day arrived new follower unfollowers via http',
#  'drewjps accepted',
#  'follow jnlazts amp http follow u back',
#  'go guy hope enjoyed update bye admin lukris',
#  'lovely day yes stay happy http',
#  'day',
#  'happy birthday momma bear love much redid found last picture grade http',
#  'k text tomorrow',
#  'rosiellis im x',
#  'love p http',
#  'nice line',
#  'playing atm',
#  'appreciate recent retweets sebpogo jessicadelpech alexandrajaafar jeandams raphaelcolas bylkana great friday',
#  'itspatgonzales follow jnlazts amp http follow u back',
#  'building product like packing suitcase plan think need remove half fully agree',
#  'royvoragen translation dostoevsky note',
#  'adamkuczynski voucher new bugatti value',
#  'someone love promise',
#  'robinadamsza converse know bra know bra get',
#  'royatv fkarsheh rahafs yummy bdayt season mnwreeen',
#  'listen jazz truck',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'tvillesocialmed ca wait speak pbevent see',
#  'waiting hq pic today add yoona x hairpin otp collection http',
#  'mastership honey',
#  'paindo want say follow p',
#  'greekgodnjh sure',
#  'awesome await report',
#  'throwback lol manny still asshole',
#  'brijresidency story structure unit encompasses bhk flat http',
#  'sajidislam honored',
#  'kielixttv know like',
#  'jamelyyyyy follow jnlazts amp http follow u back',
#  'zeddba curry close home',
#  'clash prasetyoseven milano calling',
#  'ranzkyle followback po',
#  'legit loser sit get gassed',
#  'friend saw dead thing made think aww thanks guy',
#  'speak andrewspenceim',
#  'vinkaazzahp always',
#  'vikkfollows starsquad please get follow awesome',
#  'awwww thanks galactichat',
#  'evilbluebird nicole stevieby onetwentywatts cherylynpitcher skidkidd thanks news man utc',
#  'remember one time go even though ticket still want km',
#  'oh good haha let know think',
#  'bravefrontiergl thanks give certainty problem hope u could solve least know dont hurry totem',
#  'somewhere later',
#  'good advice friday http',
#  'lunglock rhodria joseyxneko anouilhuk davidbedwell stupidfacerob queenofthesonic therealrobcook cheer alice',
#  'namraeter go http please click link checkout',
#  'goodwynspetfood two dog amp one cat good friend goodwynsgoodies freebiefriday',
#  'foowhiter ugh never rt fade moaning leeds tweet',
#  'looking forward jozi guy http',
#  'mitchfas hello found time wasnt following till',
#  'think fifth album im okay fuck http',
#  'philconcerts may available tix pa ba ng atl concert thanks',
#  'syedmohdjunaid yeah coldplay song playlist p love favorite scientist fix yellow atlas p',
#  'awesome waiting',
#  'chandsxc follow jnlazts amp http follow u back',
#  'luvjoyein done yein',
#  'yarnsbaby haha receiving ff thing friday nice way start day xx',
#  'lol selos http',
#  'jabongatpumaurbanstampede gt timely arrival jabongindia',
#  'dreesti waiter bill sir customer ok kitchen',
#  'title say http',
#  'hey almost time visit city',
#  'keep inside pocket ur wripped jean',
#  'beautiful',
#  'iloveseika well haha',
#  'celebritycruise love connie fabulous ship amazing crew staff great time',
#  'isweetan hi sweetan best ask tristanpope great day fun filming',
#  'bbosold nope',
#  'umiamaiofficial ok thanks following',
#  'mum begging watch soprano watch',
#  'kidxsa follow back please',
#  'vivienneclore oh fun',
#  'bigbraman great hear',
#  'also ff ukraine',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'ollyofficial follow please olly',
#  'beautiful via talented elmoprinssi forget http',
#  'bit tired hour salsa dancing latinmotion last night definitely worth happy friday everyone',
#  'piperdonut thanks haha tell truth',
#  'blossominglou yes pls',
#  'gotten least hour sleep past day rest week interesting',
#  'ccbmlov thank',
#  'check bro blogiversary many awesome review come http',
#  'top cutie bohol http',
#  'follow jnlazts amp http follow u back',
#  'brizzlelass briliant literally conversation post v email saw',
#  'ansriram key word annual read anyone writing',
#  'productive day far happy day head spinning thing voice keep calling lol',
#  'vaninatwilight yeheyy thank much pinya whoooah win',
#  'good morning dear friend lt listen trance lover enjoy happy friday lt http',
#  'favorite subject school physic http',
#  'lilytins congrats good news heading weekend',
#  'take head stopped',
#  'socialitepanda ब matter jungle accommodate',
#  'nejcsvete hi shouting list one best secret behind adeccowaytowork sandroforceo',
#  'youtubeactus swag',
#  'wait till turn go mia',
#  'kjorobbinsl shaymcsharon parajanitor kelseabellum thanks',
#  'lovely time flow workinprogress love choosing colour http',
#  'love finnigan loyal royal',
#  'fotoset reusful seems like somebody fun today http',
#  'miyaoliva love',
#  'quit selling young understand muntu',
#  'another gem today falco cool supersmash http',
#  'good morning hotnsexy girl amazing friskyfriday beach',
#  'jonscrazytweets welcome',
#  'theyingster afcgramachroi iwaveback lol tiring good looking',
#  'wrong turn amazing movie',
#  'leecash glad hear back see anything else crop let u know',
#  'kill http',
#  'bryanteslava pic nash coming',
#  'saneliur make sure always tissue chocolate tea every hannibal episode work way',
#  'contact u today get city bush somewhere classicassures',
#  'aguilerarmenia hi would like impastel concert let know city country start working thanks',
#  'stats day arrived new follower unfollowers via http',
#  'glad liked check nice stuff wsalelove wforwoman',
#  'chasilveo follow jnlazts amp http follow u back',
#  'thrilled first international assignment aerial camera operator wale come boom never forget smile',
#  'friday night hong kong ferry central meet new girlfriend drink http',
#  'family time dj resto http',
#  'good morning drinkt koffie',
#  'wforwoman girl wardrobe would w wsalelove',
#  'stargate atlantis cool show',
#  'great muaahhh http',
#  'seashoponline ohh hii haha thanks info check maybe di nagsend yung order form ko lt haha thanks ulit',
#  'happy birthday',
#  'trust without ugly without u',
#  'leggete qui per la chat larry http',
#  'louliveswell encouraged employer board http stuck poster http',
#  'hackadayio sticker came sponsor prize hackadayprize entry http tablet',
#  'goodnight liam hope fantastic day today sweet dream baby love heart xx',
#  'oh yeah milo aurini juicebro fucking pillar respective community',
#  'yeah boii look arrived post morning latest new bible smashingmag http',
#  'ill better soon feeling sick',
#  'lamo first fangirl hard love share platonic pic know science',
#  'morning friday happy friday beautiful people smile',
#  'ccweekuk thank set another great day supporting community amp helping resident servicewithasmile',
#  'sound good see saturday',
#  'live night two fams bloodline husky',
#  'cordermrs welcome',
#  'picture like see obituary advert goofingaround madness mad http',
#  'whirlpoolbathuk lovely giveaway freebiefriday',
#  'roofbsuzy roofyuna roofsinb roofchaelin roofaim roofjackson dah move',
#  'nothing cool totally someone bitterness anger hatred towards pure indifference',
#  'u wake suite life zach cody',
#  'oh know yes order delivered work address added address book',
#  'achieving excellence music music producer mind boggling amp fatiguing job baareeq',
#  'bexlittle lindyrendy dotnetsolutions love thanks sharing',
#  'kkiimmeenngg follow jnlazts amp http follow u back',
#  'mobiadage gamedevrobot gamedev hobby',
#  'avantikaseeth mandisatweets santherlabelle yes yes yes',
#  'thank hi please click list hair accessory amp product http',
#  'sometimes tamang hinala http',
#  'royalmail following',
#  'wonkasslilo hello babe got niam access could give something ship dm',
#  'selfieeeee http',
#  'especially three lass aling http',
#  'hi gorgeous tilliemodel nice swim si get birthday shout please would make day perfection xx',
#  'doloresssvee haha hope got work tho bout quit p',
#  'goodbye forget feminist fought right act like snobby little bitch goodnight',
#  'jamieforevs follow jnlazts amp http follow u back',
#  'caroline caroline guy say mighty fine threw little making hbd http',
#  'follback',
#  'time jogging p',
#  'place hope pro remote work traveling',
#  'newly listed ebay store http',
#  'new disneyinfinity starwars character look amazing preorder starter pack store today http',
#  'parulcoolthougs want talk',
#  'always tweet hit snap one ever worth try',
#  'homies bought skin bday',
#  'awadkum chant jai italy fast amitshahoffice narendramodi',
#  'heeeeyyy follow fan account thank',
#  'leonrestaurants uk',
#  'thank',
#  'blahkumaran woah nice nice',
#  'cutehiddlesmile u welcome',
#  'lucahollic good',
#  'review http phew literally overwhelmed',
#  'hi would like impastel concert let know city country start working thanks',
#  'amp next time house whenever',
#  'tflwaystopay got thanks g',
#  'encouraged employer board http stuck poster http',
#  'mskristinkreuk hug ang kiss philippine',
#  'entered win huge bluemicrophones package cazualluk amp marzbargaming enter http giveaway',
#  'yes work',
#  'follow jnlazts amp http follow u back',
#  'hi bridgehousethel great connect specialise thermal imaging survey need u',
#  'yeah bruise rib',
#  'pallaviruhail bhaktisbanter flipkartfashionfriday wo give dear worry',
#  'tombraider hype thought might like meloniemac http',
#  'oh oh oh thejuiceinthemix potus rela talliaoyando building homeboyzradio djbashkenya',
#  'low priority match hahaha',
#  'dxuntlesslarry fback',
#  'helpinggroupdms want harry dm bc wan na give surprise friend birthday wan na make happy',
#  'opportune time collapse chaotic cosas lt note alliteration nomalangasa barrybateman andilemlondo',
#  'sungjookxm going well oppayaa',
#  'khalidalsalem best want body',
#  'natgeo new show u ca lick ur elbow interesting',
#  'stats day arrived new follower unfollowers via http',
#  'mileycyrus emu stoked thank http creampuffshinee',
#  'woke yo trentowers fav tweet made day http',
#  'remember need people approval god approval',
#  'jisung kid sunshine http',
#  'thellamaverse mm okay thanks',
#  'message u right nicola forward brighten day helen',
#  'follow jnlazts amp http follow u back',
#  'sunofsides congrats',
#  'hi brian get shipped today take week australia many thanks http',
#  'awonderball good fun time ol bone creaking',
#  'mokhenerale eh abuti welcome tweetland lol p',
#  'thx android support xmas',
#  'phedran great skyblock stream',
#  'im standing always belieber bcause justinbieber die',
#  'boheffy streaming twitch join http',
#  'brbcody sympathy laugh',
#  'would like xo',
#  'drtychimichanga awesome',
#  'kimtaaeyeonss unnieeee',
#  'tonight night nuka penacova djset free edm kizomba latinhouse housemusic summer http',
#  'well wild ride gt',
#  'tokyotantra hahaha tell anytime wan na taste oh yer address send',
#  'mtnza thanks team yellow',
#  'acsxy maganda look pretty short hair cute',
#  'mistresssaphire good morning gorgeous mistress saphire',
#  'work busy help finish im home',
#  'thanks amazing follower instagram among yet feel free connect http',
#  'coconut sambal mussel recipe http',
#  'thanks kalin http',
#  'follow mixcloud http',
#  'fback',
#  'implodingpika thankyou greeting australia',
#  'cant work sarcasm know chelsea support think he useless come ok',
#  'ibepyari follow back',
#  'aubreysablan come back next thursday still hang hehe said hi love u',
#  'benson gorgeous thank much sharing u also enter facebook',
#  'itslukeev look solid',
#  'great night',
#  'change day good',
#  'add snapchat snapchat kikmeboys photooftheday fuck chat musicbiz sheskindahot http',
#  'fleekile mbalula said repeat love south africa',
#  'friend making fun fact mexican hurt feeling leave scarred life',
#  'sophiadelpizzo office today',
#  'jeremygutsche like amazing donut recipe share foiegras lover',
#  'despite weather today wedding going beautiful',
#  'tony stark incredible tony picture http http',
#  'sit write poem story bubbling',
#  'last night http',
#  'dale send billion kiss magical day',
#  'mcllary might work great weekend',
#  'smile friday tgif weekend http',
#  'cast vote next election jcreport',
#  'pebblehelp done thank tweet',
#  'bevanns oh piggin go yer give u peace',
#  'alelizabeth appreciate follow heard botanical soap',
#  'love u',
#  'late upload freshly old healed',
#  'oh bed haha ca sleep though day exciting',
#  'inspchin koeitecmoeurope tanikohorigome goldxfierce addictrian matthewrumple thx',
#  'nikimcglynn good think first isp',
#  'bluebellems steel bluebellems next wednesday see like',
#  'hey',
#  'camerondallas definitely love making people smile cause swear since met earlier stopped smiling love cam',
#  'sabihamahmoud except lord',
#  'neilwhoreann french fan made movie wwat france last year video photo',
#  'fixed thanks feedback',
#  'thanks everyone came stream hope guy enjoyed night',
#  'siddichan twitch yaaaaaaaay thx',
#  'looking forward reviewing http',
#  'thank beiruting',
#  'coolkidsftnjh fback',
#  'thanks updating profile page alexapoppe http',
#  'lovely coffee',
#  'cute panda make day http http',
#  'thank eonnie',
#  'stokebrisbane hi saw u follow thought u might like dark http let u know u think',
#  'favourite ciatelondon cream soda',
#  'love body fuller shit even lol happy healthy happy happy',
#  'rettweet http',
#  'dianaaortizz real mvg valuable girlfriend staying till madrid game start',
#  'sore ya',
#  'tmhcuddly excited definitely meet',
#  'morriskid coming bergerac first team left know checking chant',
#  'rizwanism choice food left individual',
#  'vickicartagena episode excellent far love adam beach movie amp looking forward seeing suicide squad next year',
#  'growing fond christopher like initially cocky really prove attitude improving',
#  'glenocsko sound good dm email address suggest date coffee',
#  'indeed many thanks',
#  'smile even pain http',
#  'hi happys http',
#  'funny intelligent strong funny funny http',
#  'hello get youth job opportunity follow gt gt tolajobjobs',
#  'mokwepa using c',
#  'ever watch certain people snapchat bc know',
#  'ok know busy',
#  'last exam',
#  'forgot u http',
#  'fun fact love meeting new people',
#  'jaseygalore know office busy feeling pity knee happened',
#  'sale fleur dress cream idr gt idr http',
#  'thankyou',
#  'follow jnlazts amp http follow u back',
#  'tompolo meeting aimed stopping sale oil find buyer',
#  'centerfxld true johngreen disappoint looking forward paper town',
#  'need know everything going okay',
#  'ltbeautyblog fdncoffee say le slacking amp getting cracking',
#  'juliewestern know name particularly striking happy day',
#  'misshollylou hey invite join scope influencer http',
#  'deewaniveronica bad mam p',
#  'francesbeeton lovely looking cake bet taste good',
#  'feytyaz follback ya',
#  'found last night let say instant stiffening interest http',
#  'rettweet http',
#  'chubanhes fback',
#  'rettweet http',
#  'follback ya',
#  'got secret grindea courier crypt possibly arma record today gosh new game look like limbo',
#  'siaramelatienza follow jnlazts amp http follow u back',
#  'myriadphoto thanks retweeting madsenjewellery orchard art show super weekend',
#  'karachi ka venice rain jaagalerts several part karachi witness accumulated rain water http',
#  'maroon cocktail dress http mididresses filipinaniah http',
#  'fback po',
#  'real quick',
#  'morning mine usually use manual really close like shooting vein crackle glaze',
#  'new layout look bomb',
#  'thanks connecting garrowlscq hope great day question ask',
#  'tweetnesian pake',
#  'gabrielaliuw hi made change design hope like http',
#  'joim feed troop http via audioboom',
#  'brand wanting review beauty product blog mail ladolcevitainluxembourg prrequest journorequest',
#  'follback ya',
#  'ssalchli good luck shaun',
#  'yes',
#  'anyone want added bot dm bot',
#  'chloegmoretz chloe watched let yesterday really awesome really talented intelligent actress beautiful',
#  'hesfallenangel could get free solo dm give away xoxo',
#  'tripverse outboundapp thanks sharing wishing wicked weekend',
#  'hola juan sending big hi houston tx fan jenni family year stumble upon video',
#  'padaleckbye choker btw',
#  'seoulsjin seouljins seouljins fine tbh',
#  'photoset sadomasochistsparadise wynter outtake sadomasochist paradise cuties http',
#  'make day smiling',
#  'ghostkidluke fback',
#  'itsrebeccarayne ty bby',
#  'please enjoy clip losing shit cypher http',
#  'athrawestokio adeccowaytowork adeccojapan next week office let go',
#  'danielcwest thank following',
#  'stats day arrived new follower unfollowers via http',
#  'purehaire amen thanks',
#  'hi bam barsandmelody follow bestfriend love lot see warsaw lt love lt',
#  'shyayen follow jnlazts amp http follow u back',
#  'drenchinwine paper girl',
#  'know would lovely pic x',
#  'adnancad planted people allowed thing every thing p',
#  'corner fucking dope getting addicted great job',
#  'bby gurl http',
#  'hey hey',
#  'nickthebullsfan cashnastygaming still suck editing turn something special owe guy',
#  'ayokejkt visit blog http thanks',
#  'daannymoncada breannelaflare ugly daniel good ape',
#  'happy bday cinemainmygenes saar great year ahead',
#  'thought might saw loved verse butterfly part bonus',
#  'thank ok fun kikbella adasamper rachellfilsoof enjoy day u http',
#  'well good morning',
#  'palakspatel would follow',
#  'busy productive day filled tear hour hour laughter today good day',
#  'hi ticket dm',
#  'yummmyyy eating dosa',
#  'bbcdoctorwho',
#  'meglovesgames probably easier meet station unless particularly want show house',
#  'huge amp warm welcome vodkablond',
#  'achi im busy next week exam hope understand cant tweet youuu bawi ako queenesther esthercarodan',
#  'leemckenzietv looking sharp',
#  'xwinnermino yes im year younger u wonder youre huge boy',
#  'playing brain dot braindots http http',
#  'ha one picture http',
#  'galatasaray ready poldi cimbom',
#  'thanks share',
#  'lostchillhoran fback',
#  'follow jnlazts amp http follow u back',
#  'graphure happy birthday buddy',
#  'thank',
#  'sigh whykaysbeauty bruhhh dopjones call daddy one time',
#  ...]

# %%
X_train, X_test, y_train, y_test = train_test_split(preprocessed_tweets, labels, test_size=0.2, random_state=42)

# %%
vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
classifier = MultinomialNB()
classifier.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = classifier.predict(X_test_tfidf)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77       988
#            1       0.78      0.73      0.76      1012
#
#     accuracy                           0.76      2000
#    macro avg       0.76      0.76      0.76      2000
# weighted avg       0.76      0.76      0.76      2000

# %%
example_tweets = [
    "I love this movie, it's amazing!",
    "This product is terrible, waste of money.",
    "Feeling happy today! #goodvibes",
    "The customer service was awful, never shopping here again.",
    "Can't wait to see my friends this weekend! #excited"
]
preprocessed_example_tweets = [preprocess_tweet(tweet) for tweet in example_tweets]
example_tweets_tfidf = vectorizer.transform(preprocessed_example_tweets)
predictions = classifier.predict(example_tweets_tfidf)
sentiment_mapping = {0: 'Negative', 1: 'Positive'}

for tweet, prediction in zip(example_tweets, predictions):
    print("Tweet:", tweet)
    print("Predicted Sentiment:", sentiment_mapping[prediction])
    print()
# Out:
# Tweet: I love this movie, it's amazing!
# Predicted Sentiment: Positive
#
# Tweet: This product is terrible, waste of money.
# Predicted Sentiment: Negative
#
# Tweet: Feeling happy today! #goodvibes
# Predicted Sentiment: Positive
#
# Tweet: The customer service was awful, never shopping here again.
# Predicted Sentiment: Negative
#
# Tweet: Can't wait to see my friends this weekend! #excited
# Predicted Sentiment: Positive
